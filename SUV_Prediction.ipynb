# %% [markdown]
# <a href="https://colab.research.google.com/github/AzizJaser/SUV-Prediction/blob/main/SUV_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score

# %%
data = pd.read_csv("/content/suv_data.csv")

data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data = data.drop(['User ID'],axis=1)
data
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0      Male   19            19000          0
# 1      Male   35            20000          0
# 2    Female   26            43000          0
# 3    Female   27            57000          0
# 4      Male   19            76000          0
# ..      ...  ...              ...        ...
# 395  Female   46            41000          1
# 396    Male   51            23000          1
# 397  Female   50            20000          1
# 398    Male   36            33000          0
# 399  Female   49            36000          1
#
# [400 rows x 4 columns]

# %%
data.isna().sum()
# Out:
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
data.dtypes
# Out:
# Gender             object
# Age                 int64
# EstimatedSalary     int64
# Purchased           int64
# dtype: object

# %%
data['Gender'] = data.Gender.map({'Male':0,'Female':1})
data
# Out:
#      Gender  Age  EstimatedSalary  Purchased
# 0         0   19            19000          0
# 1         0   35            20000          0
# 2         1   26            43000          0
# 3         1   27            57000          0
# 4         0   19            76000          0
# ..      ...  ...              ...        ...
# 395       1   46            41000          1
# 396       0   51            23000          1
# 397       1   50            20000          1
# 398       0   36            33000          0
# 399       1   49            36000          1
#
# [400 rows x 4 columns]

# %%
features = data.drop(['Purchased'],axis=1)
target = data['Purchased']

# %%
x_train,x_test,y_train,y_test = train_test_split(features,target,test_size=0.20,random_state=2)

# %%
sc = StandardScaler()
x_train = pd.DataFrame(sc.fit_transform(x_train))
x_test = pd.DataFrame(sc.fit_transform(x_test))

# %%
model_k1 = KNeighborsClassifier(n_neighbors=1)
model_k1.fit(x_train,y_train)

score = model_k1.score(x_test, y_test)
print("{:.3f}".format(score))
# Out:
# 0.900

# %%
model_k3 = KNeighborsClassifier(n_neighbors=3)
model_k3.fit(x_train,y_train)

score = model_k3.score(x_test, y_test)
print("{:.3f}".format(score))
# Out:
# 0.863

# %%
model_k5 = KNeighborsClassifier(n_neighbors=5)
model_k5.fit(x_train,y_train)

score = model_k5.score(x_test, y_test)
print("{:.3f}".format(score))
# Out:
# 0.900
